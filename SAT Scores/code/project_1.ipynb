# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# SAT Score averages in US states

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# Data looks good to start

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline
plt.style.use('fivethirtyeight')

import pandas as pd
sat_scores=pd.read_csv('.././assets/sat_scores.csv')

sat_scores.head()
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
listoflist=sat_scores.values.tolist()
listoflist
# Out:
# [['CT', 82, 509, 510],
#  ['NJ', 81, 499, 513],
#  ['MA', 79, 511, 515],
#  ['NY', 77, 495, 505],
#  ['NH', 72, 520, 516],
#  ['RI', 71, 501, 499],
#  ['PA', 71, 500, 499],
#  ['VT', 69, 511, 506],
#  ['ME', 69, 506, 500],
#  ['VA', 68, 510, 501],
#  ['DE', 67, 501, 499],
#  ['MD', 65, 508, 510],
#  ['NC', 65, 493, 499],
#  ['GA', 63, 491, 489],
#  ['IN', 60, 499, 501],
#  ['SC', 57, 486, 488],
#  ['DC', 56, 482, 474],
#  ['OR', 55, 526, 526],
#  ['FL', 54, 498, 499],
#  ['WA', 53, 527, 527],
#  ['TX', 53, 493, 499],
#  ['HI', 52, 485, 515],
#  ['AK', 51, 514, 510],
#  ['CA', 51, 498, 517],
#  ['AZ', 34, 523, 525],
#  ['NV', 33, 509, 515],
#  ['CO', 31, 539, 542],
#  ['OH', 26, 534, 439],
#  ['MT', 23, 539, 539],
#  ['WV', 18, 527, 512],
#  ['ID', 17, 543, 542],
#  ['TN', 13, 562, 553],
#  ['NM', 13, 551, 542],
#  ['IL', 12, 576, 589],
#  ['KY', 12, 550, 550],
#  ['WY', 11, 547, 545],
#  ['MI', 11, 561, 572],
#  ['MN', 9, 580, 589],
#  ['KS', 9, 577, 580],
#  ['AL', 9, 559, 554],
#  ['NE', 8, 562, 568],
#  ['OK', 8, 567, 561],
#  ['MO', 8, 577, 577],
#  ['LA', 7, 564, 562],
#  ['WI', 6, 584, 596],
#  ['AR', 6, 562, 550],
#  ['UT', 5, 575, 570],
#  ['IA', 5, 593, 603],
#  ['SD', 4, 577, 582],
#  ['ND', 4, 592, 599],
#  ['MS', 4, 566, 551],
#  ['All', 45, 506, 514]]

# %% [markdown]
# ##### 5. Print the data

# %%
print listoflist
# Out:
# [['CT', 82, 509, 510], ['NJ', 81, 499, 513], ['MA', 79, 511, 515], ['NY', 77, 495, 505], ['NH', 72, 520, 516], ['RI', 71, 501, 499], ['PA', 71, 500, 499], ['VT', 69, 511, 506], ['ME', 69, 506, 500], ['VA', 68, 510, 501], ['DE', 67, 501, 499], ['MD', 65, 508, 510], ['NC', 65, 493, 499], ['GA', 63, 491, 489], ['IN', 60, 499, 501], ['SC', 57, 486, 488], ['DC', 56, 482, 474], ['OR', 55, 526, 526], ['FL', 54, 498, 499], ['WA', 53, 527, 527], ['TX', 53, 493, 499], ['HI', 52, 485, 515], ['AK', 51, 514, 510], ['CA', 51, 498, 517], ['AZ', 34, 523, 525], ['NV', 33, 509, 515], ['CO', 31, 539, 542], ['OH', 26, 534, 439], ['MT', 23, 539, 539], ['WV', 18, 527, 512], ['ID', 17, 543, 542], ['TN', 13, 562, 553], ['NM', 13, 551, 542], ['IL', 12, 576, 589], ['KY', 12, 550, 550], ['WY', 11, 547, 545], ['MI', 11, 561, 572], ['MN', 9, 580, 589], ['KS', 9, 577, 580], ['AL', 9, 559, 554], ['NE', 8, 562, 568], ['OK', 8, 567, 561], ['MO', 8, 577, 577], ['LA', 7, 564, 562], ['WI', 6, 584, 596], ['AR', 6, 562, 550], ['UT', 5, 575, 570], ['IA', 5, 593, 603], ['SD', 4, 577, 582], ['ND', 4, 592, 599], ['MS', 4, 566, 551], ['All', 45, 506, 514]]

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
state_name=sat_scores.State.values
#sat_scores.State.tolist()
print state_name
# Out:
# ['CT' 'NJ' 'MA' 'NY' 'NH' 'RI' 'PA' 'VT' 'ME' 'VA' 'DE' 'MD' 'NC' 'GA' 'IN'
#  'SC' 'DC' 'OR' 'FL' 'WA' 'TX' 'HI' 'AK' 'CA' 'AZ' 'NV' 'CO' 'OH' 'MT' 'WV'
#  'ID' 'TN' 'NM' 'IL' 'KY' 'WY' 'MI' 'MN' 'KS' 'AL' 'NE' 'OK' 'MO' 'LA' 'WI'
#  'AR' 'UT' 'IA' 'SD' 'ND' 'MS' 'All']

# %% [markdown]
# ##### 8. Print the types of each column

# %%
sat_scores.dtypes
# Out:
# State     object
# Rate       int64
# Verbal     int64
# Math       int64
# dtype: object

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
sat_scores=sat_scores[sat_scores.State !='All']

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
#dict={x : sat_scores[x].tolist()  for x in sat_scores.columns}

sat_dict=sat_scores.to_dict('list')                               
print sat_dict
# Out:
# {'Math': [510, 513, 515, 505, 516, 499, 499, 506, 500, 501, 499, 510, 499, 489, 501, 488, 474, 526, 499, 527, 499, 515, 510, 517, 525, 515, 542, 439, 539, 512, 542, 553, 542, 589, 550, 545, 572, 589, 580, 554, 568, 561, 577, 562, 596, 550, 570, 603, 582, 599, 551], 'State': ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS'], 'Rate': [82, 81, 79, 77, 72, 71, 71, 69, 69, 68, 67, 65, 65, 63, 60, 57, 56, 55, 54, 53, 53, 52, 51, 51, 34, 33, 31, 26, 23, 18, 17, 13, 13, 12, 12, 11, 11, 9, 9, 9, 8, 8, 8, 7, 6, 6, 5, 5, 4, 4, 4], 'Verbal': [509, 499, 511, 495, 520, 501, 500, 511, 506, 510, 501, 508, 493, 491, 499, 486, 482, 526, 498, 527, 493, 485, 514, 498, 523, 509, 539, 534, 539, 527, 543, 562, 551, 576, 550, 547, 561, 580, 577, 559, 562, 567, 577, 564, 584, 562, 575, 593, 577, 592, 566]}

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
sat_scores.set_index('State').T.to_dict('list')
# Out:
# {'AK': [51, 514, 510],
#  'AL': [9, 559, 554],
#  'AR': [6, 562, 550],
#  'AZ': [34, 523, 525],
#  'CA': [51, 498, 517],
#  'CO': [31, 539, 542],
#  'CT': [82, 509, 510],
#  'DC': [56, 482, 474],
#  'DE': [67, 501, 499],
#  'FL': [54, 498, 499],
#  'GA': [63, 491, 489],
#  'HI': [52, 485, 515],
#  'IA': [5, 593, 603],
#  'ID': [17, 543, 542],
#  'IL': [12, 576, 589],
#  'IN': [60, 499, 501],
#  'KS': [9, 577, 580],
#  'KY': [12, 550, 550],
#  'LA': [7, 564, 562],
#  'MA': [79, 511, 515],
#  'MD': [65, 508, 510],
#  'ME': [69, 506, 500],
#  'MI': [11, 561, 572],
#  'MN': [9, 580, 589],
#  'MO': [8, 577, 577],
#  'MS': [4, 566, 551],
#  'MT': [23, 539, 539],
#  'NC': [65, 493, 499],
#  'ND': [4, 592, 599],
#  'NE': [8, 562, 568],
#  'NH': [72, 520, 516],
#  'NJ': [81, 499, 513],
#  'NM': [13, 551, 542],
#  'NV': [33, 509, 515],
#  'NY': [77, 495, 505],
#  'OH': [26, 534, 439],
#  'OK': [8, 567, 561],
#  'OR': [55, 526, 526],
#  'PA': [71, 500, 499],
#  'RI': [71, 501, 499],
#  'SC': [57, 486, 488],
#  'SD': [4, 577, 582],
#  'TN': [13, 562, 553],
#  'TX': [53, 493, 499],
#  'UT': [5, 575, 570],
#  'VA': [68, 510, 501],
#  'VT': [69, 511, 506],
#  'WA': [53, 527, 527],
#  'WI': [6, 584, 596],
#  'WV': [18, 527, 512],
#  'WY': [11, 547, 545]}

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
sat_scores.describe()
# Out:
#             Rate      Verbal        Math
# count  51.000000   51.000000   51.000000
# mean   37.000000  532.529412  531.843137
# std    27.550681   33.360667   36.287393
# min     4.000000  482.000000  439.000000
# 25%     9.000000  501.000000  503.000000
# 50%    33.000000  527.000000  525.000000
# 75%    64.000000  562.000000  557.500000
# max    82.000000  593.000000  603.000000

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
RX_=sat_scores.Rate.sum()/ sat_scores.Rate.count()
VX_=sat_scores.Verbal.sum()/ sat_scores.Verbal.count()
MX_=sat_scores.Math.sum()/ sat_scores.Math.count()

print 'Rate std   :  %f' % np.sqrt(sum([((x-RX_)**2) for x in sat_scores.Rate])/(sat_scores.Rate.count()-1))
print 'Verbal std : %f'% np.sqrt(sum([((x-VX_)**2) for x in sat_scores.Verbal])/(sat_scores.Verbal.count()-1))
print 'Math Std   : %f' % np.sqrt(sum([((x-MX_)**2) for x in sat_scores.Math])/(sat_scores.Math.count()-1))
# Out:
# Rate std   :  27.549955
# Verbal std : 33.361655
# Math Std   : 36.290495

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
fig=sat_scores.Rate.plot(kind='hist', figsize=(18,15),fontsize=20) # panda plot
ax=plt.gca() 
ax.set_title('Average SAT Rate Scores',fontsize=30, y=.900)
ax.set_ylabel("Frequency", fontsize=35, x=1.8)
#Bimodal

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
fig=sat_scores.Verbal.plot(kind='hist', figsize=(9,12),fontsize=20) # panda plot
ax=plt.gca() 
ax.set_title('SAT Verbal Scores',fontsize=28, y=.900, x=.80)
ax.set_ylabel("Frequency", fontsize=25, x=1.8)
#Bimodal

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
fig=sat_scores.Math.plot(kind='hist', figsize=(20,10),fontsize=20) # panda plot
ax=plt.gca() 
ax.set_title('SAT Math Scores',fontsize=30, y=.900)
ax.set_ylabel("Frequency", fontsize=35, x=1.8)
#skewed to the left

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %%
sat_scores.hist(figsize=(16,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12673eb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126988550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126a0b4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126a5db10>]], dtype=object)

# %%
#Math is symmetrical
#Rate is negatively skewed
#Verbal is bi modal

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
#point_shapes = ['+' if r == 'full' else 's' if r == 'associate' else '2' for r in rank]

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))
axes = fig.gca()
axes.scatter(sat_scores.Math, sat_scores.Verbal, s=150,
                    label=' ')

axes.set_title('Average Math vs Verbal SAT Scores in US States', fontsize=20)
axes.set_xlabel('Math', fontsize=18)
axes.set_ylabel('Verbal', fontsize=18)

for i, txt in enumerate(sat_scores.State):
    axes.annotate(txt, (sat_scores.Math[i]+.4,sat_scores.Verbal[i]+.4))

# %%
#point_shapes = ['+' if r == 'full' else 's' if r == 'associate' else '2' for r in rank]

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))
axes = fig.gca()
axes.scatter(sat_scores.Rate, sat_scores.Verbal, s=150,
                    label=' ')

axes.set_title( 'Rate vs Average Verbal SAT Scores in US States', fontsize=20)
axes.set_xlabel('Rate', fontsize=20)
axes.set_ylabel('Verbal', fontsize=18)
for i, txt in enumerate(sat_scores.State):
    axes.annotate(txt, (sat_scores.Rate[i]+.4,sat_scores.Verbal[i]+.4))

# %%
#point_shapes = ['+' if r == 'full' else 's' if r == 'associate' else '2' for r in rank]

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))
axes = fig.gca()
axes.scatter(sat_scores.Rate, sat_scores.Math, s=150,
                    label=' ')

axes.set_title('Rate vs  Average Math SAT Scores in US States', fontsize=20)
axes.set_xlabel('Rate', fontsize=18)
axes.set_ylabel('Math', fontsize=18)

for i, txt in enumerate(sat_scores.State):
    axes.annotate(txt, (sat_scores.Rate[i]+.4,sat_scores.Math[i]+.4))

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %%
#math and verbal correlation

# %%
#Math, Verbal and rate inverse correlation

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
#sat_scores.plot.box()
fig = plt.figure(figsize=(12,10))
axes = fig.gca()
axes.boxplot([sat_scores.Math,sat_scores.Verbal], patch_artist=True)
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x11c57e9d0>,
#   <matplotlib.patches.PathPatch at 0x11c5a64d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11c58d6d0>,
#   <matplotlib.lines.Line2D at 0x11c58dd10>,
#   <matplotlib.lines.Line2D at 0x11c5b3190>,
#   <matplotlib.lines.Line2D at 0x11c5b37d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11c59a9d0>,
#   <matplotlib.lines.Line2D at 0x11c5be490>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11c59a390>,
#   <matplotlib.lines.Line2D at 0x11c5b3e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11c57ee10>,
#   <matplotlib.lines.Line2D at 0x11be8a250>,
#   <matplotlib.lines.Line2D at 0x11c5a6910>,
#   <matplotlib.lines.Line2D at 0x11c5a6b10>]}

# %%
fig = plt.figure(figsize=(12,10))
axes = fig.gca()
axes.boxplot([sat_scores.Rate], patch_artist=True)
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x131030c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x13103f990>,
#   <matplotlib.lines.Line2D at 0x13103ffd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13104ac90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x13104a650>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x13103f0d0>,
#   <matplotlib.lines.Line2D at 0x13103f2d0>]}

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
sns.distplot(sat_scores.Math)
scipy.stats.mstats.normaltest(sat_scores.Math)
# Out:
# NormaltestResult(statistic=0.54841552274003325, pvalue=0.76017412403590801)

# %%
sns.distplot(sat_scores.Verbal)
scipy.stats.mstats.normaltest(sat_scores.Verbal)
# Out:
# NormaltestResult(statistic=21.525355863641892, pvalue=2.117524109156281e-05)

# %%
sns.distplot(sat_scores.Rate)
scipy.stats.mstats.normaltest(sat_scores.Rate)
# Out:
# NormaltestResult(statistic=76.221209546114068, pvalue=2.8104421166109834e-17)

# %%
# Out:
# NormaltestResult(statistic=0.54841552274003325, pvalue=0.76017412403590801)
